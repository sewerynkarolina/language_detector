# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO

def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text

# %%
file_paths = ['/home/marcin/Dane/arushanyan/Bangladesh/AktarAlMamunHossain.pdf', 
             '/home/marcin/Dane/arushanyan/Bangladesh/AlamHoque.pdf']

import glob
file_paths = glob.glob("/home/marcin/Dane/*/*/*.pdf")[1:100]

# %%
l = []
for file in file_paths:
    l.append(len(convert_pdf_to_txt(file)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-904c78c0d1c2> in <module>
#       1 l = []
#       2 for file in file_paths:
# ----> 3     l.append(len(convert_pdf_to_txt(file)))
#       4
#
# <ipython-input-2-1465da5f5fb4> in convert_pdf_to_txt(path)
#      19
#      20     for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
# ---> 21         interpreter.process_page(page)
#      22
#      23     text = retstr.getvalue()
#
# ~/anaconda3/lib/python3.7/site-packages/pdfminer/pdfinterp.py in process_page(self, page)
#     850             ctm = (1, 0, 0, 1, -x0, -y0)
#     851         self.device.begin_page(page, ctm)
# --> 852         self.render_contents(page.resources, page.contents, ctm=ctm)
#     853         self.device.end_page(page)
#     854         return
#
# ...

# %%
l
# Out:
# [30531,
#  44922,
#  27391,
#  37770,
#  40562,
#  28270,
#  32978,
#  74422,
#  46747,
#  60954,
#  34596,
#  30448,
#  49518,
#  40946,
#  50933,
#  28552,
#  67625,
#  2952,
#  60544,
#  28573,
#  31531,
#  40682,
#  68297,
#  105043,
#  18650,
#  19713,
#  41514,
#  30847,
#  48981,
#  4063,
#  32602,
#  32248,
#  16570,
#  64883,
#  48170,
#  42218,
#  47085,
#  30826,
#  28294,
#  35546,
#  21425,
#  60174,
#  80631,
#  23880,
#  22084,
#  66744,
#  32741,
#  41173,
#  15811,
#  36724,
#  43756,
#  40855,
#  28933,
#  20405,
#  97050,
#  32542,
#  65094,
#  43494]

# %%
file_paths[59]
len(l)
# Out:
# 58

# %%
convert_pdf_to_txt(file_paths[57])
# Out:
# 'Hindawi\nEducation Research International\nVolume 2018, Article ID 8719012, 8 pages\nhttps://doi.org/10.1155/2018/8719012\n\nResearch Article\nAssessment of Student Performance for Course Examination\nUsing Rasch Measurement Model: A Case Study of Information\nTechnology Fundamentals Course\n\nAmir Mohamed Talib ,1 Fahad Omar Alomary,2 and Hanan Fouad Alwadi1\n1Information Technology Department, College of Computer and Information Sciences, Al-Imam Mohammad Ibn Saud Islamic\nUniversity, Riyadh, Saudi Arabia\n2"e Executive Director of Center of Cyber Crimes Studies, Al-Imam Mohammad Ibn Saud Islamic University, Riyadh,\nSaudi Arabia\n\nCorrespondence should be addressed to Amir Mohamed Talib; ganawa53@yahoo.com\n\nReceived 27 March 2017; Accepted 11 December 2017; Published 19 February 2018\n\nAcademic Editor: Gwo-Jen Hwang\n\nCopyright © 2018 Amir Mohamed Talib et al. ,is is an open access article distributed under the Creative Commons Attribution\nLicense, which permits unrestricte
# ...
